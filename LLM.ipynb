# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarajitak0/DBS-Customer-/blob/main/LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain openAI chromadb

# %%
from langchain.document_loaders import CSVLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
import os

# %%
os.environ["OPENAI_API_KEY"]= "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"

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/house_prices.csv"

# %%
df=pd.read_csv(path)

# %%
df.head(5)
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# ...

# %%
# !wget https://in.docworkspace.com/d/sICDS9NG-AcDX1qgG
# Out:
# --2023-09-28 16:38:08--  https://in.docworkspace.com/d/sICDS9NG-AcDX1qgG
# Resolving in.docworkspace.com (in.docworkspace.com)... 15.206.225.236, 65.2.25.106
# Connecting to in.docworkspace.com (in.docworkspace.com)|15.206.225.236|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://in.docs.wps.com/module/common/loadPlatform?sid=sICDS9NG-AcDX1qgG&v=v2 [following]
# --2023-09-28 16:38:09--  https://in.docs.wps.com/module/common/loadPlatform?sid=sICDS9NG-AcDX1qgG&v=v2
# Resolving in.docs.wps.com (in.docs.wps.com)... 3.7.220.4, 35.154.135.129
# Connecting to in.docs.wps.com (in.docs.wps.com)|3.7.220.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://in.docs.wps.com/module/common/loadPlatform/?sid=sICDS9NG-AcDX1qgG&v=v2 [following]
# --2023-09-28 16:38:10--  http://in.docs.wps.com/module/common/loadPlatform/?sid=sICDS9NG-AcDX1qgG&v=v2
# ...

# %%
loader=CSVLoader(file_path='/content/sample_data/house_prices.csv')

# %%
import shutil

# Define the source and destination paths
source_path = "/content/drive/My Drive/house_prices.csv"
destination_path = "/content/sample_data/house_prices.csv"

# Move the file
shutil.move(source_path, destination_path)
# Out:
# '/content/sample_data/house_prices.csv'

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.5 MB/s eta 0:00:00
# ...

# %%
index_creator=VectorstoreIndexCreator()
docsearch=index_creator.from_loaders([loader])
